# %%
#Imports

# %%
import os
import pickle
import matplotlib.pyplot as plt
import cv2 as cv

# %%
#Definimos o path da pasta das imagens(caracteristícas)

# %%
path_to_watch = os.getcwd() + "\\annotations"
print(path_to_watch)
# Out:
# c:\Users\nosco\Desktop\GANs\annotations

# %%
#Dicionário com o nome das imagens e com o respetivo vetor de características
# feature 1 -> eyebrows distribuition  0 - 2
# feature 2 -> eyebrows shape 0 - 3 
# feature 3 -> eyebrows size 0 - 2
# feature 4 -> eyelashes size 1 - 3 
# feature 5 -> eyelids shape 1 - 2 
# feature 6 -> iris color 1 - 4 
# feature 7 -> skin color 1 - 4 
# feature 8 -> skin texture 1 - 4 
# feature 9 -> spots number  1 - 2
# y : [x,x,x,x,x,x,x,x,x]


images = {

    
}

# %%
0
# Out:
# 0

# %%
for fich in os.listdir(path_to_watch + "\\spots\\number\\2-2"):
    if(len(images[fich]) == 8):
        images[fich].append(2)

# %%
pickle.dump( images, open("needed_correct_images.p", "wb" ) )

# %%
#Função to verify se os dados estão a ser introduzidos corretamente
def Verify_introducao(num):
    count = 0
    for key in images.keys():
        if len(images[key]) == 9:
            continue
        else:
            count += 1

    if count == 0:
        print("Todas as imagens estão bem ! ")
    else:
        print("{} imagens não estão bem.".format(count))
    return True

# %%
print(Verify_introducao(9))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c0342c08a593> in <module>
# ----> 1 print(Verify_introducao(9))
#
# <ipython-input-6-b85075a5d5b0> in Verify_introducao(num)
#       2 def Verify_introducao(num):
#       3     count = 0
# ----> 4     for key in images.keys():
#       5         if len(images[key]) == 9:
#       6             continue
#
# NameError: name 'images' is not defined

# %%
images_all = pickle.load(open("needed_correct_images.p",'rb'))

# %%
def fill_none_images():
    for k in images.keys():
        if len(images[k]) != 9:
            images[k].append(-1)


fill_none_images()

# %%
def fill_images():
    for k in images_all.keys():
        if k not in images.keys():
            images[k] = []

fill_images()

# %%
print(len(images_all))
# Out:
# 10250

# %%
for i in images_all.keys():
    print(images_all[i])
# Out:
#  1, 2, 1, 3, 3, 1, 0]
# [2, 2, 1, 2, 1, 3, 3, 1, 0]
# [2, 2, 1, 2, 1, 3, 3, 1, 0]
# [2, 2, 1, 2, 1, 3, 3, 1, 0]
# [2, 2, 1, 2, 1, 3, 3, 1, 0]
# [2, 2, 1, 2, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# [2, 2, 2, 3, 1, 3, 3, 1, 0]
# ...

# %%
def find(name, path):
    for root, dirs, files in os.walk(path):
        if name in files:
            return os.path.join(root, name)

# %%
categories = [ "eyebrows distribuition",
                "eyebrows shape", 
                " eyebrows size ",
                "eyelashes size ",
                "eyelids shape" ,
                "iris color ",
                "skin color ",
                "skin texture",
                "spots number ",
    ]

# %%
categories_path = {
    (0,0) : "\\annotations\\eyebrows\\distribution\\0-sparse",
    (0,1) : "\\annotations\\eyebrows\\distribution\\1-average",
    (0,2) : "\\annotations\\eyebrows\\distribution\\2-dense",
    (1,0) : "\\annotations\\eyebrows\\shape\\0-angular",
    (1,1) : "\\annotations\\eyebrows\\shape\\1-straight",
    (1,2) : "\\annotations\\eyebrows\\shape\\2-round",
    (1,3) : "\\annotations\\eyebrows\\shape\\3-Sshape",
    (1,3) : "\\annotations\\eyebrows\\shape\\3-Sshape",
    (2,0) : "\\annotation\\eyebrows\\size\\0-small",
    (2,1) : "\\annotation\\eyebrows\\size\\1-medium",
    (2,2) : "\\annotation\\eyebrows\\size\\2-large",
    (3,1) : "\\annotations\\eyelashes\\size\\small",
    (3,2) : "\\annotations\\eyelashes\\size\\2-medium",
    (3,3) : "\\annotations\\eyelashes\\size\\3-large",
    (4,1) : "\\annotations\\eyelids\\shape\\1-normal",
    (4,2) : "\\annotations\\eyelids\\shape\\2-fall",
    (5,1) : "\\annotations\\iris\\color\\1-blue",
    (5,2) : "\\annotations\\iris\\color\\2-green",
    (5,3) : "\\annotations\\iris\\color\\3-brown",
    (5,4) : "\\annotations\\iris\\color\\4-dark brown",
    (6,1) : "\\annotations\\skin\\color\\1-black",
    (6,2) : "\\annotations\\skin\\color\\2-tanned",
    (6,3) : "\\annotations\\skin\\color\\3-white",
    (6,4) : "\\annotations\\skin\\color\\4-extreme white",
    (7,1) : "\\annotations\\skin\\texture\\1-young",
    (7,2) : "\\annotations\\skin\\texture\\2-young_plus",
    (7,3) : "\\annotations\\skin\\texture\\3-adult",
    (7,4) : "\\annotations\\skin\\texture\\4-aged",
    (8,0) : "\\annotations\\spots\\number\0-0",
    (8,1) : "\\annotations\\spots\\number\1-1",
    (8,2) : "\\annotations\\spots\\number\2-2",
    
}

# %%
#Script para corrigir as imagens
for image in images_all.keys():
    image_path = find(image,path_to_watch)
    #Lemos a imagem
    img = cv.imread(image_path)


    #Convertemos para rgb
    im_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    
  
    missing = []
    aux = 0
    c = 0
    for i in images_all[image]:
        if i == -1:
            aux = 1
            missing.append(c)
        c += 1
    print(missing)


    for miss in missing:
        print("The {} category is missing. Ver a imagem e escolher a quanto pertence!".format(categories[miss]))
        number = input("Numero a meter na categoria : ")

    if(aux == 1):
          #Mostramos a imagem
        plt.figure()
        plt.imshow(im_rgb) 
        plt.show()  
        break
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [1]
# The eyebrows shape category is missing. Ver a imagem e escolher a quanto pertence!

# %%
# Out:
# \annotations\eyebrows\distribution\1-average
